# %% [markdown]
# ## 1. Importing and Cleaning Data

# %%
# !pip install geopy
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.18.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geopy) (1.49)
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                    --> 2020.4.5.1-hecc5488_0     conda-forge
#     certifi:         2020.4.5.1-py36_0             --> 2020.4.5.1-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# certifi-2020.4.5.1   | 151 KB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# ca-certificates-2020 | 146 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import urllib.request

from bs4 import BeautifulSoup

print('Libraries imported.')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-51-10ba03bd4b80> in <module>
#      27 from bs4 import BeautifulSoup
#      28
# ---> 29 from geopy.geocoders import geocoder # import geocoder
#      30
#      31 print('Libraries imported.')
#
# ImportError: cannot import name 'geocoder'

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page, "lxml")

# %% [markdown]
# Adding Wiki to DF

# %%
A=[]
B=[]
C=[]


for row in right_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))

# %%
df=pd.DataFrame(A,columns=['PostalCode'])
df['Borough']=B
df['Neighborhood']=C

# %% [markdown]
# Cleaning Data

# %%
df['PostalCode'] = df['PostalCode'].map(lambda x: x.rstrip('\n'))
df['Borough'] = df['Borough'].map(lambda x: x.rstrip('\n'))
df['Neighborhood'] = df['Neighborhood'].map(lambda x: x.rstrip('\n'))

# %%
df=df[df.Borough != 'Not assigned']

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#   PostalCode           Borough                                 Neighborhood
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## 2. Finding Coordinates

# %% [markdown]
# ### First we pull the data

# %%
# !wget -O Geospatial_data.csv http://cocl.us/Geospatial_data
# Out:
# --2020-05-18 15:16:10--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.48.113.194, 158.85.108.86, 158.85.108.83
# Connecting to cocl.us (cocl.us)|169.48.113.194|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2020-05-18 15:16:10--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|169.48.113.194|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-05-18 15:16:11--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.29.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.29.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-05-18 15:16:11--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-05-18 15:16:11--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.29.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.29.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!CDXlpYBhE7lgq9-ytEQKMT7SJNrXXt44RjaAeivhl9xTnlJE_c10rFGDJhAuLbcDJ1tAuI0wHHWlZKxgecFbo9tnpX5w3NJfs1MdFoBO-EEQjv1urpY3fv44-cy9vP6Y-vU05kq0Be41CqM9HKzXoGU5zceVayO3iQ1HCJDfj-n_3FqfnFUmzzsDrFGCXqb5ufVxAYbw4Foe92utPc5nLiMG6dwNunSkfdp_llqoB-CiQMuA0KdxmKGsNcbCPtTElFy5YqTNHX-9sMRmsXi7Cr9SffBloefawPuGl2fQPcXeoy2e9jyYCUnHXP9vJhV-5iMvWF1-MdZ1bjaTSzB7kfRHAl6QmTQv1Z2XcLHnDVvl9l4MnSXiDp02k8FCH8xHrqPNKfNlzIh6SAZk1xJM9AuM57-Z8dQW8pLQkE3efSEXcuYi98RNfza_XAqG3EdVyyuQB4B2p0H2c_c6rGeD2m1jiG6AIsjXKL_4vCcZW6_nT0GHjYEvflR_NYk0FTuHogrCcC94_C4JQfycyChjRWOeAhGkomdaTEcyxmzANF2NvUWQxEeBYh4buD-n9qrH5Gpx7UnUZg2Upsc-KKpXXh4lJklJQoFpIT-BMaAftHBmMFXwgJA1EabgMkqgAKdPBLzAus4ypxcWotYI9Q0v5VvAAMqWgeRt4hx0Q0533of5AmTvwJ9KPWGtOcnp6phIuA1cR25hw4zS23QrZIrorOusXqdw_Fp_xRQB-CifCnmvoQSL7et44Npol-nOYCJlKPoqI8pS0hUoSIwXL8iY9r74nGGmejZs8p4GB44l-CQVpauV1ys71VZr2OWlpcLz4vqMZ67qqlwRtB7i1Pc9xIc2jo6QhNga4DBMeFKU9X882MjU-PPv0a40uOrOIuLn0s_-8LlSczqjPpY_kaOpT6Vih0whBR470gPKr_KQsQVaUEea-XYfjm4MolePTvrxg02-NN783OWfpT-BKmplig5MYHR1W6AmFbIh0ZR8Y9UqNFPq2e-L9MWrA1R1AR9Ku65YcfTeTOrkEZ_T7GG87k8Um6PE9VBlV3NvRdI4wdeozfLSoNgwSbJTulE8gYDjCaBTzYJeNRX1kSvBWzRrALcPaajB_TDkxWSietNg_4seYpq8mGHaf1pjr5qDNcfGN71HF4-EWquK240gdv8J6az4mM60-J45vZ7Z7iDun1ps5e-n7VUq-cNgdTi_wFCvdNmnistvJCS_1cKF3kmNkZFiq7PEld1AROFwVWZ5daQtCg1JBxF3KgomsPZ1vzQCXf1czyUOJjwhmBLFuRiLNlltgsT5qJb3ifnICuLNcS-wM8BuVdBc0WTHC9G5kWh8kkcBMFr8RvxgA6NpwHvINYfSqB9wSyx2DAqXWmGvKPn2J3pBzkEboQkDiznGMum7r6BHPNvif2yMgN7N26-VryRROUYJlp27h6npzYikjxc./download [following]
# --2020-05-18 15:16:12--  https://public.boxcloud.com/d/1/b1!CDXlpYBhE7lgq9-ytEQKMT7SJNrXXt44RjaAeivhl9xTnlJE_c10rFGDJhAuLbcDJ1tAuI0wHHWlZKxgecFbo9tnpX5w3NJfs1MdFoBO-EEQjv1urpY3fv44-cy9vP6Y-vU05kq0Be41CqM9HKzXoGU5zceVayO3iQ1HCJDfj-n_3FqfnFUmzzsDrFGCXqb5ufVxAYbw4Foe92utPc5nLiMG6dwNunSkfdp_llqoB-CiQMuA0KdxmKGsNcbCPtTElFy5YqTNHX-9sMRmsXi7Cr9SffBloefawPuGl2fQPcXeoy2e9jyYCUnHXP9vJhV-5iMvWF1-MdZ1bjaTSzB7kfRHAl6QmTQv1Z2XcLHnDVvl9l4MnSXiDp02k8FCH8xHrqPNKfNlzIh6SAZk1xJM9AuM57-Z8dQW8pLQkE3efSEXcuYi98RNfza_XAqG3EdVyyuQB4B2p0H2c_c6rGeD2m1jiG6AIsjXKL_4vCcZW6_nT0GHjYEvflR_NYk0FTuHogrCcC94_C4JQfycyChjRWOeAhGkomdaTEcyxmzANF2NvUWQxEeBYh4buD-n9qrH5Gpx7UnUZg2Upsc-KKpXXh4lJklJQoFpIT-BMaAftHBmMFXwgJA1EabgMkqgAKdPBLzAus4ypxcWotYI9Q0v5VvAAMqWgeRt4hx0Q0533of5AmTvwJ9KPWGtOcnp6phIuA1cR25hw4zS23QrZIrorOusXqdw_Fp_xRQB-CifCnmvoQSL7et44Npol-nOYCJlKPoqI8pS0hUoSIwXL8iY9r74nGGmejZs8p4GB44l-CQVpauV1ys71VZr2OWlpcLz4vqMZ67qqlwRtB7i1Pc9xIc2jo6QhNga4DBMeFKU9X882MjU-PPv0a40uOrOIuLn0s_-8LlSczqjPpY_kaOpT6Vih0whBR470gPKr_KQsQVaUEea-XYfjm4MolePTvrxg02-NN783OWfpT-BKmplig5MYHR1W6AmFbIh0ZR8Y9UqNFPq2e-L9MWrA1R1AR9Ku65YcfTeTOrkEZ_T7GG87k8Um6PE9VBlV3NvRdI4wdeozfLSoNgwSbJTulE8gYDjCaBTzYJeNRX1kSvBWzRrALcPaajB_TDkxWSietNg_4seYpq8mGHaf1pjr5qDNcfGN71HF4-EWquK240gdv8J6az4mM60-J45vZ7Z7iDun1ps5e-n7VUq-cNgdTi_wFCvdNmnistvJCS_1cKF3kmNkZFiq7PEld1AROFwVWZ5daQtCg1JBxF3KgomsPZ1vzQCXf1czyUOJjwhmBLFuRiLNlltgsT5qJb3ifnICuLNcS-wM8BuVdBc0WTHC9G5kWh8kkcBMFr8RvxgA6NpwHvINYfSqB9wSyx2DAqXWmGvKPn2J3pBzkEboQkDiznGMum7r6BHPNvif2yMgN7N26-VryRROUYJlp27h6npzYikjxc./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.25.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.25.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_data.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2020-05-18 15:16:12 (334 MB/s) - ‘Geospatial_data.csv’ saved [2891/2891]

# %%
df_loc = pd.read_csv('Geospatial_data.csv')
df_loc.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ### Matching Lat and Long with DF

# %%
df_tot = df.join(df_loc.set_index('Postal Code'), on='PostalCode')
df_tot.head()
# Out:
#   PostalCode           Borough                                 Neighborhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# ## 3. Clustering

# %% [markdown]
# ### Finding coordinates for Toronto

# %%
address = 'Toronto, ON'

location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# ### Making the Map

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, label in zip(df_tot['Latitude'], df_tot['Longitude'], df_tot['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
